# %% [markdown]
# # Homework 4
#
# In this assignment, you will build and evaluate machine learning models using two different datasets.
#
# - In **Questions 1–3**, you will work with a garment worker productivity dataset and build classification models using Naïve Bayes and Support Vector Machines (SVMs).
# - In **Questions 4–5**, you will work with a dataset of binary bitstrings and apply clustering and dimensionality reduction techniques.
#
# ---
#
# ## Submission Requirements
#
# Submit the pdf file with all requested outputs.
# - ensure you have run all cells before submitting
# - ensure you select each question in gradescope appropriately
# - look at your pdf before submitting, ensure it is not unreadable or cutting off outputs.
# ---
#
# ## Allowed Libraries
#
# You may use:
# - `numpy`
# - `scipy`
# - `pandas`
# - `scikit-learn`
# - `cvxpy`
# - `imbalanced-learn`
#
# You may additionally use standard Python libraries and any libraries explicitly used in lecture or discussion materials.
#
# Unless otherwise specified, you may use implementations from `scikit-learn`. You are not required to implement  algorithms from scratch.
#
# ---
#
# ## Other Notes
#
# - Do not worry about achieving very high accuracy. Model performance is not the primary grading criterion for this assignment.
# - Unless explicitly specified, you are not required to perform hyperparameter tuning. However, you are welcome to experiment with tuning if you would like.
#
# ---
#
# ## Troubleshooting
#
# If you encounter issues importing `imblearn`:
#
# 1. Run the installation code cell provided below.
# 2. Restart the kernel using:
#    `Kernel > Restart Kernel`
# 3. Re-run the notebook cells.
# 4. Test the installation with:
#
# ```python
# import imblearn

# %% [markdown]
# # Part 1: Classification on Garment Productivity Data (Q1–Q3)
#
# ## Background
#
# In this section, you will build classification models using a dataset containing information about garment manufacturing teams and their productivity.
#
# [Dataset source](https://archive.ics.uci.edu/dataset/597/productivity+prediction+of+garment+employees)
#
# ---
#
# ## Dataset Attribute Information
#
# 1. **date**: Date in MM-DD-YYYY format
# 2. **day**: Day of the week
# 3. **quarter**: Portion of the month (months are divided into four quarters)
# 4. **department**: Associated department
# 5. **team_no**: Team identifier
# 6. **no_of_workers**: Number of workers in the team
# 7. **no_of_style_change**: Number of product style changes
# 8. **targeted_productivity**: Productivity target assigned to the team
# 9. **smv**: Standard Minute Value (allocated production time)
# 10. **wip**: Work in progress (unfinished items)
# 11. **over_time**: Overtime worked in minutes
# 12. **incentive**: Financial incentive amount (in BDT)
# 13. **idle_time**: Production interruption time
# 14. **idle_men**: Number of idle workers during interruptions
# 15. **actual_productivity**: Actual productivity achieved, ranging from 0 to 1
#
# ---
#
# ## Notes for Questions 1–3
#
# The prediction target will be derived from `actual_productivity`. Specific preprocessing instructions will be provided in the corresponding questions.
#
# Some attributes are categorical (for example: `day`, `quarter`, and `department`) and may require preprocessing before training machine learning models.

# %% [markdown]
# ## Exercise 1 - General Data Preprocessing (0 points)
#
# Our dataset needs cleaning before building any models. Some of the cleaning tasks are common in general, but depends on what kind of models we are building, sometimes we have to do additional processing. These additional tasks will be mentioned in each of the remaining two exercises later.
#
# Note that **we will be using this processed data from exercise 1 in each of the remaining two exercises**.
#
# For convenience, here are the attributes that we would treat as **categorical attributes**: `day`, `quarter`, `department`, and `team`.
#
#  - Drop the column `date`.
#  - For each of the categorical attributes, **print out** all the unique elements.
#  - For each of the categorical attributes, remap the duplicated items, if you find there are typos or spaces among the duplicated items.
#      - For example, "a" and "a " should be the same, so we need to update "a " to be "a".
#      - Another example, "apple" and "appel" should be the same, so you should update "appel" to be "apple".
#
#
#  - Create another column named `satisfied` that records the productivity performance. The behavior defined as follows. **This is the dependent variable we'd like to classify in this assignment.**
#      - Return True or 1 if `actual_productivity` is equal to or greater than `targeted_productivity`. Otherwise, return False or 0, which means the team fails to meet the expected performance.
#  - Drop the columns `actual_productivity` and `targeted_productivity`.
#
#
#  - Find and **print out** which columns/attributes that have empty values, e.g., NA, NaN, null, None.
#  - Fill the empty values with 0.

# %% [markdown]
# ## Exercise 2 - Naïve Bayes Classifier (35 points in total)
#
# ### Exercise 2.1 - Additional Data Preprocessing (5 points)
#
# To build a Naïve Bayes Classifier, we need to further encode our categorical variables.
#
#  - For each of the **categorical attribtues**, encode the set of categories to be **0 ~ (n_classes - 1)**.
#      - For example, \["paris", "paris", "tokyo", "amsterdam"\] should be encoded as \[1, 1, 2, 0\].
#      - Note that the order does not really matter, i.e., \[0, 0, 1, 2\] also works. But you have to start with 0 in your encodings.
#      - You can find information about this encoding in the discussion materials.
#
#
#  - Split the data into training and testing set with the ratio of 80:20.
#
# Output your training data

# %% [markdown]
# ### Exercise 2.2 - Naïve Bayes Classifier for Categorical Attributes (15 points)
#
# Use the categorical attributes **only**, please build a Categorical Naïve Bayes classifier that predicts the column `satisfied`. <br >
# Report the **testing result** using `classification_report`. See scikit-learn.

# %% [markdown]
# ### Exercise 2.3 - Naïve Bayes Classifier for Numerical Attributes (15 points)
#
# Use the numerical attributes **only**, please build a Gaussian Naïve Bayes classifier that predicts the column `satisfied`. <br >
# Report the **testing result** using `classification_report`.
#
# **Remember to scale your data. The scaling method is up to you.**

# %% [markdown]
# ## Exercies 3 - SVM Classifier (35 points in total)
#
# ### Exercise 3.1 - Additional Data Preprocessing (5 points)
#
# To build a SVM Classifier, we need a different encoding for our categorical variables.
#
#  - For each of the **categorical attribtues**, encode them with **one-hot encoding**.
#      - You can find information about this encoding in the discussion materials.
#
#
#  - Split the data into training and testing set with the ratio of 80:20.
#
# Output your training data.

# %% [markdown]
# ### Exercise 3.2 - SVM with Different Kernels (15 points)
#
# Using all the attributes we have, please build a SVM that predicts the column `satisfied`. <br >
# Specifically, please
#  - Build one SVM with **linear kernel**.
#  - Build another SVM but with **rbf kernel**.
#  - Report the **testing results** of **both models** using `classification report`.
#
# The kernel is the only setting requirement. <br >
# Other hyperparameter tuning is not required. But make sure they are the same in these two SVMs if you'd like to tune the model. In other words, the only difference between the two SVMs should be the kernel setting.
#
# **Remember to scale your data. The scaling method is up to you.**

# %% [markdown]
# ### Exercise 3.3 - SVM with Over-sampling (15 points)
#  - For the column `satisfied` in our **training set**, please **print out** the frequency of each class.
#  - Oversample the **training data**.
#  - For the column `satisfied` in the oversampled data, **print out** the frequency of each class  again.
#  - Re-build the 2 SVMs with the same setting you have in Exercise 3.2, but **use oversampled training data** instead.
#      - Do not forget to scale the data first. As always, the scaling method is up to you.
#  - Report the **testing result** with `classification_report`.
#
# You can use ANY methods listed on [here](https://imbalanced-learn.org/stable/references/over_sampling.html#) such as RandomOverSampler or SMOTE. <br >
# You are definitely welcomed to build your own oversampler. <br >
#
# Note that you do not have to over-sample your testing data.

# %% [markdown]
# # Part 2: Clustering and Dimensionality Reduction on Bitstring Data (Q4–Q5)
#
# For Questions 4–5, you will work with a dataset containing 1200 binary bitstrings, each consisting of 16 bits. The `modified_bitstrings.csv` dataset is provided.
#
# In this section, you will:
# - apply agglomerative clustering
# - compare it with k-means clustering
# - use PCA for visualization and dimensionality reduction
#
# ---
#
# ## Background and Data Information
#
# For a bitstring S, we write:
#
# S = (s15, s14, s13, ..., s0)
#
# where:
# - s15 is the most significant bit (MSB)
# - s0 is the least significant bit (LSB)
#
# There are duplicated bitstrings in the dataset. You do not need to remove them.
#
# ---
#
# The dataset consists of 16-bit binary vectors. You will treat each bitstring as a point in 16-dimensional space and compare clustering methods on this representation.

# %% [markdown]
# ## Exercise 4 - Clustering on Bitstring Data (30 points total)
#
# In this exercise, you will compare agglomerative clustering and k-means clustering on binary bitstring data.
#
# ---
#
# ### Exercise 4.1 - Agglomerative Clustering and K-Means (15 points)
#
# 1. Apply agglomerative clustering to the dataset.
#    - Choose a distance threshold and clustering configuration that produces a reasonable grouping structure. (look for something around 30-80 clusters)
#       - Please use ward linkage which relies on Euclidian distance. And set n_clusters=none: AgglomerativeClustering(n_clusters=None, distance_threshold=???, linkage="ward")
#       - You will need to decide distance_metric. Think on what makes sense here and what distance between bitsrings means.
#    - Report the number of clusters discovered.
#
# 2. Using the number of clusters found in Part 1 as the value of k, apply k-means clustering to the same dataset.
#
# 3. For both clustering methods:
#    - Compute the number of samples assigned to each cluster.
#    - Visualize the cluster frequencies using a bar chart or another clear visualization.

# %% [markdown]
# ### Exercise 4.2 - Comparing Agglomerative Clustering and K-Means (15 points)
#
# Based on your results from Exercise 4.1, answer the following questions:
#
# 1. What are the major differences between agglomerative clustering and k-means clustering?
#
# 2. Why do these methods produce different clustering behavior on the bitstring dataset?

# %% [markdown]
# ## Exercise 5 - Principal Component Analysis (Optional but Recommended)
#
# In this exercise, you will use PCA to visualize the structure of the bitstring dataset in 2D.
#
# ---
#
# ### Exercise 5.1 - K-Means Clustering with k = 2
#
# 1. Apply k-means clustering to the dataset with k = 2.
#
# 2. Report the number of samples in each cluster.
#
# 3. Visualize the cluster size distribution (e.g., bar chart).

# %% [markdown]
# ### Exercise 5.2 - PCA Visualization
#
# 1. Reduce the dataset to 2 dimensions using Principal Component Analysis (PCA).
#
# 2. Create a scatter plot of the data in the 2D PCA space.
#
# 3. Color each point according to its k = 2 cluster assignment from Exercise 5.1.
#
# 4. Briefly comment on whether the clusters appear separable in the PCA projection.
